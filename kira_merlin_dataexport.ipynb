# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# Make the graphs a bit prettier, and bigger
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 5)

# %%
df = pd.read_excel('Merlin_DataExport_7_1.xlsx',index_col='FORMATTED DATE_TIME')
df.plot()
# Out:
# <Axes: xlabel='FORMATTED DATE_TIME'>

# %%
df[:3]
# Out:
#                      Temperature  Wet Bulb Temp  Globe Temperature  \
# FORMATTED DATE_TIME
# 2024-06-18 11:31:00         80.8           54.1               80.4
# 2024-06-18 11:31:00         78.4           53.4               78.4
# 2024-06-18 11:31:00         81.2           53.6               82.1
#
#                      Relative Humidity  Barometric Pressure  Altitude  \
# FORMATTED DATE_TIME
# 2024-06-18 11:31:00               14.9                27.83      1983
# 2024-06-18 11:31:00               16.7                27.85      1966
# 2024-06-18 11:31:00               13.3                27.83      1980
#
#                      Station Pressure  Wind Speed  Heat Index  Dew Point  ...  \
# FORMATTED DATE_TIME                                                       ...
# 2024-06-18 11:31:00             27.83         0.0        75.6       28.8  ...
# 2024-06-18 11:31:00             27.85         0.0        73.4       29.5  ...
# ...

# %%
df['Location'].value_counts()
# Out:
# Location
# Cab        38936
# Cargo      38753
# Out        29958
# Outside     7994
# Name: count, dtype: int64

# %%
# df['FORMATTED DATE_TIME'] = pd.to_datetime(df['FORMATTED DATE_TIME'],format='%m/%d/%y %H:%M')

# %%
df[:3]
# Out:
#                      Temperature  Wet Bulb Temp  Globe Temperature  \
# FORMATTED DATE_TIME
# 2024-06-18 11:31:00         80.8           54.1               80.4
# 2024-06-18 11:31:00         78.4           53.4               78.4
# 2024-06-18 11:31:00         81.2           53.6               82.1
#
#                      Relative Humidity  Barometric Pressure  Altitude  \
# FORMATTED DATE_TIME
# 2024-06-18 11:31:00               14.9                27.83      1983
# 2024-06-18 11:31:00               16.7                27.85      1966
# 2024-06-18 11:31:00               13.3                27.83      1980
#
#                      Station Pressure  Wind Speed  Heat Index  Dew Point  ...  \
# FORMATTED DATE_TIME                                                       ...
# 2024-06-18 11:31:00             27.83         0.0        75.6       28.8  ...
# 2024-06-18 11:31:00             27.85         0.0        73.4       29.5  ...
# ...

# %%
Cab = df[df['Location']=='Cab']
Cargo = df[df['Location'] == 'Cargo']
Out = df[df['Location'] == 'Out']
Outside = df[df['Location'] == 'Outside']

# %%
Cab['Temperature'].plot()
# Out:
# <Axes: xlabel='FORMATTED DATE_TIME'>

# %%
Locations = [Cab, Cargo, Out, Outside]
LocName = ["Cab", "Cargo", 'Out', 'Outside']

# %%
for i in range(4):
    Locations[i]['Temperature'].plot()
    Locations[i]['Wet Bulb Temp'].plot()
    Locations[i]['Globe Temperature'].plot()
    plt.title(LocName[i])
    plt.figure()

# %%
MerlinCargo = df[(df['Technology'] == 'Merlin') & (df['Location'] == 'Cargo')]
MerlinCargoDates = MerlinCargo[(MerlinCargo['Date'] == '6/27/24')]
BaselineCargo = df[(df['Technology'] == 'Baseline') & (df['Location'] == 'Cargo')]
BaselineCargoDates = BaselineCargo[(BaselineCargo['Date'] == '6/27/24')]

# %%
MerlinCargoDates['Temperature'].plot()
# MerlinCargoDates['Wet Bulb Temp'].plot()
MerlinCargoDates['Globe Temperature'].plot()
MerlinCargoDates['Heat Index'].plot()
plt.title('Merlin')
plt.legend()
plt.figure()

BaselineCargoDates['Temperature'].plot()
# BaselineCargoDates['Wet Bulb Temp'].plot()
BaselineCargoDates['Globe Temperature'].plot()
BaselineCargoDates['Heat Index'].plot()
plt.title('Baseline')
plt.legend()
plt.figure()

# %%
MerlinCargoDates['Heat Index'].plot()
BaselineCargoDates['Heat Index'].plot()
plt.title('Merlin vs Baseline')
plt.legend(["Merlin", "Baseline"])
plt.xlabel("Date Time")
plt.ylabel("Degrees (C)")
# Out:
# Text(0, 0.5, 'Degrees (C)')

# %%
dates = ['6/27/24','6/28/24', '7/1/24']
for date in dates:
    for i in range(2):
        Locations[i]['Heat Index'][(Locations[i]['Date'] == date) & (Locations[i]['Vehicle'] == 'CDV') & (Locations[i]['Technology'] == 'Merlin')].plot()
    plt.legend([LocName[0],LocName[1]])
    plt.title(date)
    plt.figure()
